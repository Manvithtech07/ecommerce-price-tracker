# %% [markdown]
# ### Phase 2 : Exploratory Data Analysis (EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('amazon_laptops.csv')
df
# Out:
#                                                  Title     Price  Rating  \
# 0    Samsung Galaxy Book4 (Gray, 16GB RAM, 512GB SS...   53990.0     4.1
# 1    Samsung Galaxy Book4 (Gray, 16GB RAM, 512GB SS...   62990.0     3.8
# 2    HP Victus, AMD Ryzen 9-8945HS, 8GB RTX 4060, 1...   99990.0     3.8
# 3    ASUS TUF Gaming A15, AMD Ryzen 7 7435HS Gaming...   64990.0     4.2
# 4    ASUS TUF A16 (2025), AMD Ryzen 7 7445HS, Gamin...   89990.0     4.0
# ..                                                 ...       ...     ...
# 421  ASUS TUF Gaming A14, AMD Ryzen 7 8845HS Gaming...  114990.0     3.2
# 422  MSI Thin 15, Intel 13th Gen. Core i5-13420H, 4...   59990.0     4.1
# 423  MSI Thin 15, Intel 12th Gen. i7-12650H, 40CM F...   74953.0     4.0
# 424  ASUS Gaming V16 (2025) 14th Gen,Intel Core 5 2...   77790.0     4.0
# 425  HP Victus, 13th Gen Intel Core i5-13420H, 4GB ...   62990.0     3.8
#
#     Reviews                                               Link
# 0       120  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1        21  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2       343  https://www.amazon.in/HP-9-8945HS-Upgrade-300n...
# 3       608  https://www.amazon.in/ASUS-15-6-inch-GeForce-G...
# 4        57  https://www.amazon.in/ASUS-7445HS-4050-6GB-Win...
# ..      ...                                                ...
# 421       5  https://www.amazon.in/ASUS-Processor-GeForce-W...
# 422      69  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 423      11  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 424      47  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 425     550  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
#
# [426 rows x 5 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Title    426 non-null    object
#  1   Price    405 non-null    float64
#  2   Rating   350 non-null    float64
#  3   Reviews  350 non-null    object
#  4   Link     426 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 16.8+ KB
#                Price      Rating
# count     405.000000  350.000000
# mean   110715.029630    3.996286
# std     83724.499657    0.577330
# min     22995.000000    1.000000
# 25%     67990.000000    3.800000
# 50%     77790.000000    4.000000
# 75%    115020.000000    4.200000
# max    617990.000000    5.000000

# %%
df.isnull().sum()
# Out:
# Title       0
# Price      21
# Rating     76
# Reviews    76
# Link        0
# dtype: int64

# %%
df_clean = df.dropna(subset=['Price']).copy()
df_clean['Rating'] = df_clean['Rating'].fillna(0)
df_clean['Reviews'] = df_clean['Reviews'].fillna(0)

# %%
df_clean.isnull().sum()
# Out:
# Title      0
# Price      0
# Rating     0
# Reviews    0
# Link       0
# dtype: int64

# %%
df.shape
# Out:
# (426, 5)

# %%
def clean_reviews(value):
    if pd.isna(value):
        return 0
    value = str(value).replace(",", "") 
    if "K" in value.upper():
        return int(float(value.upper().replace("K", "")) * 1000)
    try:
        return int(float(value)) 
    except:
        return 0

df_clean['Reviews'] = df_clean['Reviews'].apply(clean_reviews)

# %%
df_clean['Price'] = pd.to_numeric(df_clean['Price'].astype(str).str.replace(",", ""), errors='coerce').fillna(0).astype(int)
df_clean['Rating'] = pd.to_numeric(df_clean['Rating'], errors='coerce').fillna(0.0)
print(df_clean.dtypes)
# Out:
# Title       object
# Price        int64
# Rating     float64
# Reviews      int64
# Link        object
# dtype: object

# %%
df_clean['Brand'] = df_clean['Title'].apply(lambda x: x.split()[0].upper())
df_clean
# Out:
#                                                  Title   Price  Rating  \
# 0    Samsung Galaxy Book4 (Gray, 16GB RAM, 512GB SS...   53990     4.1
# 1    Samsung Galaxy Book4 (Gray, 16GB RAM, 512GB SS...   62990     3.8
# 2    HP Victus, AMD Ryzen 9-8945HS, 8GB RTX 4060, 1...   99990     3.8
# 3    ASUS TUF Gaming A15, AMD Ryzen 7 7435HS Gaming...   64990     4.2
# 4    ASUS TUF A16 (2025), AMD Ryzen 7 7445HS, Gamin...   89990     4.0
# ..                                                 ...     ...     ...
# 421  ASUS TUF Gaming A14, AMD Ryzen 7 8845HS Gaming...  114990     3.2
# 422  MSI Thin 15, Intel 13th Gen. Core i5-13420H, 4...   59990     4.1
# 423  MSI Thin 15, Intel 12th Gen. i7-12650H, 40CM F...   74953     4.0
# 424  ASUS Gaming V16 (2025) 14th Gen,Intel Core 5 2...   77790     4.0
# 425  HP Victus, 13th Gen Intel Core i5-13420H, 4GB ...   62990     3.8
#
#      Reviews                                               Link    Brand
# 0        120  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  SAMSUNG
# 1         21  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  SAMSUNG
# 2        343  https://www.amazon.in/HP-9-8945HS-Upgrade-300n...       HP
# 3        608  https://www.amazon.in/ASUS-15-6-inch-GeForce-G...     ASUS
# 4         57  https://www.amazon.in/ASUS-7445HS-4050-6GB-Win...     ASUS
# ..       ...                                                ...      ...
# 421        5  https://www.amazon.in/ASUS-Processor-GeForce-W...     ASUS
# 422       69  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      MSI
# 423       11  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...      MSI
# 424       47  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...     ASUS
# 425      550  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...       HP
#
# [405 rows x 6 columns]

# %%
df_clean.to_csv("amazon_laptops_cleaned.csv", index=False)
